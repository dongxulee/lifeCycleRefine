# %%
# %pylab inline
from solveMDP_richLow import * 
Vgrid = np.load("richLow.npy")
matplotlib.rcParams['figure.figsize'] = [16, 8]
plt.rcParams.update({'font.size': 15})
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # simulation with real shock based on empirical data

# %%
import pandas as pd
df_1999 = pd.read_csv("df_1999_30to60.csv")
df = df_1999[(df_1999["skillLevel"] == "High")&(df_1999["financeExperience"] == "Yes")]
df["ab"] = 30
df["wealth"] = df["liquidWealth"] + df["investmentAmount"]
codes = {'employed':1, 'unemployed': 0, "retired": 0}
df["employmentStatus"] = df["employmentStatus"].map(codes)
codes = {'owner':1, 'renter': 0}
df["ownership"] = df["ownership"].map(codes)
initialStates = df[["ageHead","wealth","ab","year","employmentStatus","ownership","participation"]]
initialStates["year"] = imaginedEconState[0]
initialStates = jnp.array(initialStates.values)

# risk free interest rate depending on current S state 
bondReturn = jnp.array(econRate[:,2])
# stock return depending on current S state
stockReturn = jnp.array(econRate[:,1])

@partial(jit, static_argnums=(0,))
def transition_real(t,age,a,x):
    '''
        Input:
            x = [w,ab,s,e,o,z] single action 
            x = [0,1, 2,3,4,5] 
            a = [c,b,k,h,action] single state
            a = [0,1,2,3,4]
        Output:
            w_next
            ab_next
            s_next
            e_next
            o_next
            z_next
            
            prob_next
    '''
    s = jnp.array(x[2], dtype = jnp.int8)
    e = jnp.array(x[3], dtype = jnp.int8)
    # actions taken
    b = a[1]
    k = a[2]
    action = a[4]
    w_next = ((1+bondReturn[t])*b + (1+stockReturn[t])*k).repeat(nE)
    ab_next = (1-x[4])*(t*(action == 1)).repeat(nE) + x[4]*(x[1]*jnp.ones(nE))
    s_next = econ[t+1].repeat(nE)
    e_next = jnp.array([e,(1-e)])*(t+age-20<T_R) + jnp.array([0,0])*(t+age-20>=T_R)
    z_next = x[5]*jnp.ones(nE) + ((1-x[5]) * (k > 0)).repeat(nE)
    # job status changing probability and econ state transition probability
    pe = Pe[s, e]
    prob_next = jnp.array([1-pe, pe])
    # owner
    o_next_own = (x[4] - action).repeat(nE)
    # renter
    o_next_rent = action.repeat(nE)
    o_next = x[4] * o_next_own + (1-x[4]) * o_next_rent   
    return jnp.column_stack((w_next,ab_next,s_next,e_next,o_next,z_next,prob_next))

'''
    # [w,ab,s,e,o,z]
    # w explicitly 
    # assume ab = 30 the strong assumption we made 
    # s is known 
    # e is known 
    # o is known
    # z is known
'''
from jax import random

def simulation(key, period = yearCount):
    x = initialStates[key.sum()%initialStates.shape[0]][1:]
    age = int(initialStates[key.sum()%initialStates.shape[0]][0])
    path = []
    move = []
    for t in range(0, period):
        key, subkey = random.split(key)
        if t == T_max-1:
            _,a = V_solve(t + age - 20,Vgrid[:,:,:,:,:,:,t + age - 20],x)
        else:
            _,a = V_solve(t + age - 20,Vgrid[:,:,:,:,:,:,t + age - 20],x)
        xp = transition_real(t,age,a,x)           
        p = xp[:,-1]
        x_next = xp[:,:-1]
        path.append(x)
        move.append(a)
        x = x_next[random.choice(a = nE, p=p, key = subkey)]
    path.append(x)
    return jnp.array(path), jnp.array(move)

# total number of agents
num = initialStates.shape[0] * 10
# simulation part 
keys = vmap(random.PRNGKey)(jnp.arange(num))
path = []
move = []
for i in tqdm(range(len(keys))):
    p,m = simulation(keys[i])
    path.append(p)
    move.append(m)
Paths = jnp.array(path)
Moves = jnp.array(move)
# Out:
#   0%|          | 0/1110 [00:11<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-db7c2ba35fa5> in <module>
#      94 move = []
#      95 for i in tqdm(range(len(keys))):
# ---> 96     p,m = simulation(keys[i])
#      97     path.append(p)
#      98     move.append(m)
#
# <ipython-input-4-db7c2ba35fa5> in simulation(key, period)
#      77             _,a = V_solve(t + age - 20,Vgrid[:,:,:,:,:,:,t + age - 20],x)
#      78         else:
# ---> 79             _,a = V_solve(t + age - 20,Vgrid[:,:,:,:,:,:,t + age - 20],x)
#      80         xp = transition_real(t,age,a,x)
#      81         p = xp[:,-1]
#
# ~/lifeCycleRefine/20211117/solveMDP_richLow.py in V_solve(t, V_next, x)
#     423         prob_next 6
#     424     '''
# --> 425     actions = feasibleActions(t,x)
#     426     xp = transition(t,actions,x)
#     427     # bequeath utility, wealth level, the retirement account, heir sell the house at a cost of 25k
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.8/site-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     403       _check_arg(arg)
#     404     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 405     out_flat = xla.xla_call(
#     406         flat_fun, *args_flat,
#     407         device=device, backend=backend, name=flat_fun.__name__,
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1612
#    1613   def bind(self, fun, *args, **params):
# -> 1614     return call_bind(self, fun, *args, **params)
#    1615
#    1616   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1603       params_tuple, out_axes_transforms)
#    1604   tracers = map(top_trace.full_raise, args)
# -> 1605   outs = primitive.process(top_trace, fun, tracers, params)
#    1606   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1607
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1615
#    1616   def process(self, trace, fun, tracers, params):
# -> 1617     return trace.process_call(self, fun, tracers, params)
#    1618
#    1619   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     611
#     612   def process_call(self, primitive, f, tracers, params):
# --> 613     return primitive.impl(f, *tracers, **params)
#     614   process_map = process_call
#     615
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(***failed resolving arguments***)
#     617                    donated_invars, inline):
#     618   del inline  # Only used at tracing time
# --> 619   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     620                                *unsafe_map(arg_spec, args))
#     621   try:
#
# ~/anaconda3/lib/python3.8/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     260       fun.populate_stores(stores)
#     261     else:
# --> 262       ans = call(fun, *args)
#     263       cache[key] = (ans, fun.stores)
#     264
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     694
#     695   abstract_args, arg_devices = unzip2(arg_specs)
# --> 696   jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(
#     697       fun, abstract_args, pe.debug_info_final(fun, "jit"))
#     698   if any(isinstance(c, core.Tracer) for c in consts):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals, debug_info)
#    1283     main.jaxpr_stack = ()  # type: ignore
#    1284     with core.new_sublevel():
# -> 1285       jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1286     del fun, main
#    1287   return jaxpr, out_avals, consts
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1261     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1262     in_tracers = map(trace.new_arg, in_avals)
# -> 1263     ans = fun.call_wrapped(*in_tracers)
#    1264     out_tracers = map(trace.full_raise, ans)
#    1265     jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/lifeCycleRefine/20211117/solveMDP_richLow.py in feasibleActions(t, x)
#     297     # this is the fire sell term, as long as we could afford the payment, do not sell
#     298     sell = (yAT(t,x) + x[0] + payment > 0)*jnp.zeros(nA) + (yAT(t,x) + x[0] + payment <= 0)*jnp.ones(nA)
# --> 299     budget1 = yAT(t,x) + x[0] + (1-sell)*payment + sell*(H*pt - Ms[t-ab] - c_s)
#     300     h = jnp.ones(nA)*H*(1+kappa)*(1-sell) + sell*jnp.clip(budget1*As[:,0]*(1-alpha)/pr, a_max = Rl)
#     301     c = budget1*As[:,0]*(1-sell) + sell*(budget1*As[:,0] - h*pr)
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.8/site-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     403       _check_arg(arg)
#     404     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 405     out_flat = xla.xla_call(
#     406         flat_fun, *args_flat,
#     407         device=device, backend=backend, name=flat_fun.__name__,
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1612
#    1613   def bind(self, fun, *args, **params):
# -> 1614     return call_bind(self, fun, *args, **params)
#    1615
#    1616   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1603       params_tuple, out_axes_transforms)
#    1604   tracers = map(top_trace.full_raise, args)
# -> 1605   outs = primitive.process(top_trace, fun, tracers, params)
#    1606   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1607
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1615
#    1616   def process(self, trace, fun, tracers, params):
# -> 1617     return trace.process_call(self, fun, tracers, params)
#    1618
#    1619   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#    1070     in_avals = [t.aval for t in tracers]
#    1071     with core.new_sublevel():
# -> 1072       jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(f, self.main, in_avals)
#    1073     if params.get('inline', False):
#    1074       return core.eval_jaxpr(jaxpr, consts, *tracers)
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1261     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1262     in_tracers = map(trace.new_arg, in_avals)
# -> 1263     ans = fun.call_wrapped(*in_tracers)
#    1264     out_tracers = map(trace.full_raise, ans)
#    1265     jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/lifeCycleRefine/20211117/solveMDP_richLow.py in yAT(t, x)
#     248 @partial(jit, static_argnums=(0,))
#     249 def yAT(t,x):
# --> 250     yt = y(t, x)
#     251     if t < T_R:
#     252         # yi portion of the income will be put into the 401k if employed
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.8/site-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     403       _check_arg(arg)
#     404     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 405     out_flat = xla.xla_call(
#     406         flat_fun, *args_flat,
#     407         device=device, backend=backend, name=flat_fun.__name__,
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1612
#    1613   def bind(self, fun, *args, **params):
# -> 1614     return call_bind(self, fun, *args, **params)
#    1615
#    1616   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1603       params_tuple, out_axes_transforms)
#    1604   tracers = map(top_trace.full_raise, args)
# -> 1605   outs = primitive.process(top_trace, fun, tracers, params)
#    1606   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1607
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1615
#    1616   def process(self, trace, fun, tracers, params):
# -> 1617     return trace.process_call(self, fun, tracers, params)
#    1618
#    1619   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#    1070     in_avals = [t.aval for t in tracers]
#    1071     with core.new_sublevel():
# -> 1072       jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(f, self.main, in_avals)
#    1073     if params.get('inline', False):
#    1074       return core.eval_jaxpr(jaxpr, consts, *tracers)
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1261     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1262     in_tracers = map(trace.new_arg, in_avals)
# -> 1263     ans = fun.call_wrapped(*in_tracers)
#    1264     out_tracers = map(trace.full_raise, ans)
#    1265     jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/lifeCycleRefine/20211117/solveMDP_richLow.py in y(t, x)
#     239     if t < T_R:
#     240         if os.path.exists("richLow.npy"):
# --> 241             return detEarning[t] * (1+gGDP[t]) * x[3] + (1-x[3]) * welfare
#     242         else:
#     243             return detEarning[t] * (1+gGDP[jnp.array(x[2], dtype = jnp.int8)]) * x[3] + (1-x[3]) * welfare
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in __add__(self, other)
#     507   def __ge__(self, other): return self.aval._ge(self, other)
#     508   def __abs__(self): return self.aval._abs(self)
# --> 509   def __add__(self, other): return self.aval._add(self, other)
#     510   def __radd__(self, other): return self.aval._radd(self, other)
#     511   def __sub__(self, other): return self.aval._sub(self, other)
#
# ~/anaconda3/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    5922     if not isinstance(other, _scalar_types + _arraylike_types + (core.Tracer,)):
#    5923       return NotImplemented
# -> 5924     return binary_op(self, other)
#    5925   return deferring_binary_op
#    5926
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.8/site-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     403       _check_arg(arg)
#     404     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 405     out_flat = xla.xla_call(
#     406         flat_fun, *args_flat,
#     407         device=device, backend=backend, name=flat_fun.__name__,
#
# KeyboardInterrupt:

# %%
keys

# %%
# x = [w,ab,s,e,o,z]
# x = [0,1, 2,3,4,5]
ws = Paths[:,:,0].T
ab = Paths[:,:,1].T
ss = Paths[:,:,2].T
es = Paths[:,:,3].T
os = Paths[:,:,4].T
zs = Paths[:,:,5].T
cs = Moves[:,:,0].T
bs = Moves[:,:,1].T
ks = Moves[:,:,2].T
hs = Moves[:,:,3].T
ms = Ms[jnp.append(jnp.array([0]),jnp.arange(yearCount)).reshape(-1,1) - jnp.array(ab, dtype = jnp.int8)]*os

# %%
np.save("w1", ws)

# %%
np.save("waseozcbkhm1", np.array([ws,ab,ss,es,os,zs,cs,bs,ks,hs,ms]))
